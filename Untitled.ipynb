# %% [markdown]
# # Overview

# %% [markdown]
# ## Business Problem

# %% [markdown]
# ## Business Value

# %% [markdown]
# # Data

# %% [markdown]
# ## Data Loading/ Understanding

# %%
import gzip
import csv
import json
import pandas as pd
import numpy as np;

# %%
pwd
# Out:
# 'D:\\Flatiron\\Project1\\dsc-phase-1-project'

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is C649-A6AD
#
#  Directory of D:\Flatiron\Project1\dsc-phase-1-project
#
# 08/23/2021  05:25 AM    <DIR>          .
# 08/23/2021  05:25 AM    <DIR>          ..
# 08/15/2021  03:30 PM               152 .canvas
# 08/15/2021  03:30 PM                80 .gitignore
# 08/15/2021  03:32 PM    <DIR>          .ipynb_checkpoints
# 08/15/2021  03:30 PM         1,425,341 awesome.gif
# 08/15/2021  03:30 PM             1,846 CONTRIBUTING.md
# 08/22/2021  11:10 AM    <DIR>          jupyter_contrib_nbextensions
# 08/15/2021  03:30 PM             1,357 LICENSE.md
# 08/15/2021  03:30 PM             4,676 README.md
# 08/15/2021  03:30 PM             1,022 student.ipynb
# 08/23/2021  05:25 AM           623,309 Untitled.ipynb
# 08/23/2021  02:29 AM    <DIR>          zippedData
#                8 File(s)      2,057,783 bytes
#                5 Dir(s)  2,000,011,747,328 bytes free

# %%
cd zippedData/
# Out:
# D:\Flatiron\Project1\dsc-phase-1-project\zippedData

# %%
movie_gross  = pd.read_csv('bom.movie_gross.csv.gz', compression = 'gzip')
movie_gross.head(1)
# Out:
#          title studio  domestic_gross foreign_gross  year
# 0  Toy Story 3     BV     415000000.0     652000000  2010

# %%
name_basics  = pd.read_csv('imdb.name.basics.csv.gz', compression = 'gzip')
name_basics.head(1)
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
#
#                           primary_profession  \
# 0  miscellaneous,production_manager,producer
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553

# %%
akas   = pd.read_csv('imdb.title.akas.csv.gz', compression = 'gzip')
akas.head(1)
# Out:
#     title_id  ordering          title region language types attributes  \
# 0  tt0369610        10  Джурасик свят     BG       bg   NaN        NaN
#
#    is_original_title
# 0                0.0

# %%
basics = pd.read_csv('imdb.title.basics.csv.gz', compression = 'gzip')
basics.head(1)
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres
# 0  Action,Crime,Drama

# %%
crew   = pd.read_csv('imdb.title.crew.csv.gz', compression = 'gzip')
crew.head(1)
# Out:
#       tconst  directors    writers
# 0  tt0285252  nm0899854  nm0899854

# %%
principals = pd.read_csv('imdb.title.principals.csv.gz', compression = 'gzip')
principals.head(1)
# Out:
#       tconst  ordering     nconst category  job   characters
# 0  tt0111414         1  nm0246005    actor  NaN  ["The Man"]

# %%
ratings = pd.read_csv('imdb.title.ratings.csv.gz', compression = 'gzip')
ratings.head(1)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31

# %%
movie_info = pd.read_csv('rt.movie_info.tsv.gz', compression = 'gzip', delimiter="\t")
movie_info.head(1)
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
#
#                                  genre          director          writer  \
# 0  Action and Adventure|Classics|Drama  William Friedkin  Ernest Tidyman
#
#   theater_date      dvd_date currency box_office      runtime studio
# 0  Oct 9, 1971  Sep 25, 2001      NaN        NaN  104 minutes    NaN

# %%
reviews = pd.read_csv('rt.reviews.tsv.gz', compression = 'gzip', delimiter= "\t",encoding = 'unicode_escape')
reviews.head(1)
# Out:
#    id                                             review rating  fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5  fresh
#
#        critic  top_critic        publisher               date
# 0  PJ Nabarro           0  Patrick Nabarro  November 10, 2018

# %%
movies = pd.read_csv('tmdb.movies.csv.gz', compression = 'gzip')
movies.head(1)
# Out:
#    Unnamed: 0        genre_ids     id original_language  \
# 0           0  [12, 14, 10751]  12444                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788

# %%
budgets = pd.read_csv('tn.movie_budgets.csv.gz', compression = 'gzip')
budgets.head(1)
# Out:
#    id  release_date   movie production_budget domestic_gross worldwide_gross
# 0   1  Dec 18, 2009  Avatar      $425,000,000   $760,507,625  $2,776,345,279

# %% [markdown]
# ## Data Preparation

# %%
# def genres_sort(x):
#     x = x.split(',')[0]      
#     return x

def revise_str_to_int(x):
    if isinstance(x,str):
        x = float(x.replace(',', '').replace('$', ''))
    else:
        x = 0        
    return x

# %%
movie_rating = akas.merge(ratings, left_on = 'title_id', right_on = 'tconst')
movie_rating = movie_rating.merge(basics, left_on = 'tconst', right_on = 'tconst')
movie_rating = movie_rating.drop_duplicates(subset=['primary_title'])
movie_rating_with_crew = movie_rating.drop_duplicates(subset=['primary_title'])
movie_rating.head(1)
# Out:
#     title_id  ordering          title region language types attributes  \
# 0  tt0369610        10  Джурасик свят     BG       bg   NaN        NaN
#
#    is_original_title     tconst  averagerating  numvotes   primary_title  \
# 0                0.0  tt0369610            7.0    539338  Jurassic World
#
#    original_title  start_year  runtime_minutes                   genres
# 0  Jurassic World        2015            124.0  Action,Adventure,Sci-Fi

# %%
budgets['production_budget'] = budgets['production_budget'].map(revise_str_to_int)
budgets['worldwide_gross'] = budgets['worldwide_gross'].map(revise_str_to_int)
budgets['profit_ratio'] = (budgets['worldwide_gross']/budgets['production_budget'])
update_budgets = budgets.sort_values(by='profit_ratio', ascending = False)
update_budgets.head()
# Out:
#       id  release_date                    movie  production_budget  \
# 5745  46  Jun 30, 1972              Deep Throat            25000.0
# 5613  14  Mar 21, 1980                  Mad Max           200000.0
# 5492  93  Sep 25, 2009      Paranormal Activity           450000.0
# 5679  80  Jul 10, 2015              The Gallows           100000.0
# 5406   7  Jul 14, 1999  The Blair Witch Project           600000.0
#
#      domestic_gross  worldwide_gross  profit_ratio
# 5745    $45,000,000       45000000.0   1800.000000
# 5613     $8,750,000       99750000.0    498.750000
# 5492   $107,918,810      194183034.0    431.517853
# 5679    $22,764,410       41656474.0    416.564740
# 5406   $140,539,099      248300000.0    413.833333

# %%
ignore1 = ['language', 'types', 'tconst', 'is_original_title', 'region', 'attributes', 'original_title', 'title']
movie_rating = movie_rating.drop(ignore1, axis = 1)
movie_rating = movie_rating.sort_values(by='averagerating', ascending = False)

# %%
movie_rating.loc['genres'] = movie_rating['genres'].str.split().str.get(0)
movie_gross['foreign_gross'] = movie_gross['foreign_gross'].map(revise_str_to_int)

# %%
movie_rating = movie_rating[movie_rating['genres'].notnull()]
# movie_rating['genres'] = movie_rating['genres'].map(genres_sort)
ignore2 = ['ordering', 'averagerating', 'numvotes','title_id']
movie_rating = movie_rating.drop(ignore2, axis = 1)
movie_rating.head(10)
# Out:
#                                             primary_title  start_year  \
# 150912                                    Revolution Food      2015.0
# 54768      Exteriores: Mulheres Brasileiras na Diplomacia      2018.0
# 162413                              I Was Born Yesterday!      2015.0
# 195998                The Paternal Bond: Barbary Macaques      2015.0
# 212159                    Fly High: Story of the Disc Dog      2019.0
# 184717                              Requiem voor een Boom      2016.0
# 206826  Ellis Island: The Making of a Master Race in A...      2018.0
# 251823                                     Calamity Kevin      2019.0
# 182419                                      All Around Us      2019.0
# 53172                                Freeing Bernie Baran      2010.0
#
#         runtime_minutes               genres
# 150912             70.0          Documentary
# 54768              52.0          Documentary
# 162413             31.0          Documentary
# 195998             59.0          Documentary
# 212159             65.0          Documentary
# 184717             48.0          Documentary
# 206826             70.0  Documentary,History
# 251823             77.0     Adventure,Comedy
# 182419              NaN          Documentary
# 53172             100.0    Crime,Documentary

# %%
from itertools import chain

# return list from series of comma-separated strings
def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

# calculate lengths of splits
lens = movie_rating['genres'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
movie_rating = pd.DataFrame({'primary_title': np.repeat(movie_rating['primary_title'], lens),
                    'start_year': np.repeat(movie_rating['start_year'], lens),
                    'runtime_minutes': np.repeat(movie_rating['runtime_minutes'], lens),
                    'genres': chainer(movie_rating['genres'])})

movie_rating.head(10)
# Step 1
# We start with creating a new dataframe from the series with EmployeeId as the index
# movie_rating = pd.DataFrame(movie_rating.genres.str.split(',').tolist(), index=movie_rating.primary_title).stack()
# # Step 2
# # We now want to get rid of the secondary index
# # To do this, we will make EmployeeId as a column (it can't be an index since the values will be duplicate)
# movie_rating = movie_rating.reset_index([0, 'primary_title'])
# # Step 3
# # The final step is to set the column names as we want them
# movie_rating.columns = ['primary_title', 'start_year','runtime_minutes','genres']
# Out:
#                                             primary_title  start_year  \
# 150912                                    Revolution Food      2015.0
# 54768      Exteriores: Mulheres Brasileiras na Diplomacia      2018.0
# 162413                              I Was Born Yesterday!      2015.0
# 195998                The Paternal Bond: Barbary Macaques      2015.0
# 212159                    Fly High: Story of the Disc Dog      2019.0
# 184717                              Requiem voor een Boom      2016.0
# 206826  Ellis Island: The Making of a Master Race in A...      2018.0
# 206826  Ellis Island: The Making of a Master Race in A...      2018.0
# 251823                                     Calamity Kevin      2019.0
# 251823                                     Calamity Kevin      2019.0
#
#         runtime_minutes       genres
# 150912             70.0  Documentary
# 54768              52.0  Documentary
# 162413             31.0  Documentary
# 195998             59.0  Documentary
# 212159             65.0  Documentary
# 184717             48.0  Documentary
# 206826             70.0  Documentary
# 206826             70.0      History
# 251823             77.0    Adventure
# 251823             77.0       Comedy

# %%
movie_rating = movie_rating.merge(update_budgets, left_on = 'primary_title', right_on = 'movie')

movie_rating = movie_rating.set_index('start_year').sort_index()

movie_rating['genres'].value_counts()

# below_average_condition = df[df['OverallCond'] < 5]
# movie_rating['averagerating'].plot.hist()
# Out:
# Drama          1101
# Comedy          658
# Action          537
# Adventure       415
# Thriller        374
# Crime           313
# Horror          270
# Romance         260
# Sci-Fi          176
# Mystery         174
# Biography       166
# Fantasy         159
# Animation       123
# Family          120
# Documentary     112
# Music            65
# History          54
# Sport            46
# War              26
# Western          14
# Musical          11
# News              1
# Name: genres, dtype: int64

# %%
ignore3 = ['id', 'release_date', 'movie', 'domestic_gross', 'production_budget', 'profit_ratio', 'primary_title', 'runtime_minutes']
movie_type_yearly_change = movie_rating.drop(ignore3, axis = 1)
movie_type_yearly_change = movie_type_yearly_change.reset_index()
movie_type_yearly_change.head(10)
# Out:
#    start_year     genres  worldwide_gross
# 0      2010.0      Sport         408159.0
# 1      2010.0     Comedy       86796502.0
# 2      2010.0    Fantasy      223050874.0
# 3      2010.0     Family      223050874.0
# 4      2010.0  Adventure      223050874.0
# 5      2010.0      Drama         109383.0
# 6      2010.0      Drama       24687524.0
# 7      2010.0    Romance       24687524.0
# 8      2010.0      Drama        1869928.0
# 9      2010.0     Family       27469621.0

# %%
movie_type_yearly_change['typr_worldwide_gross'] = movie_type_yearly_change.groupby(["genres", "start_year"])["worldwide_gross"].transform(sum)
ignore4 = ['worldwide_gross']
movie_type_yearly_change = movie_type_yearly_change.drop(ignore4, axis = 1)
movie_type_yearly_change = movie_type_yearly_change.drop_duplicates()

# movie_type_yearly_change.head(30)
movie_type_yearly_change = movie_type_yearly_change.pivot(index='start_year', columns='genres', values='typr_worldwide_gross')

movie_type_yearly_change.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='start_year'>

# %%
# import seaborn as sns
# sns.lineplot(data=movie_type_yearly_change, x="start_year", y="typr_worldwide_gross")

# %%
movie_rating.corr()
# Out:
#                    runtime_minutes        id  production_budget  \
# runtime_minutes           1.000000 -0.049314           0.341076
# id                       -0.049314  1.000000          -0.062244
# production_budget         0.341076 -0.062244           1.000000
# worldwide_gross           0.300475 -0.037656           0.782909
# profit_ratio             -0.025696  0.016387          -0.045857
#
#                    worldwide_gross  profit_ratio
# runtime_minutes           0.300475     -0.025696
# id                       -0.037656      0.016387
# production_budget         0.782909     -0.045857
# worldwide_gross           1.000000      0.080536
# profit_ratio              0.080536      1.000000

# %%
movie_rating.corr()['worldwide_gross']
# Out:
# runtime_minutes      0.300475
# id                  -0.037656
# production_budget    0.782909
# worldwide_gross      1.000000
# profit_ratio         0.080536
# Name: worldwide_gross, dtype: float64

# %%
movie_rating.corr()['worldwide_gross'].nlargest(2)
# Out:
# worldwide_gross      1.000000
# production_budget    0.782909
# Name: worldwide_gross, dtype: float64

# %%
movie_rating.corr()["worldwide_gross"].nsmallest(3)
# Out:
# id                -0.037656
# profit_ratio       0.080536
# runtime_minutes    0.300475
# Name: worldwide_gross, dtype: float64

# %%
movie_rating_with_crew = movie_rating_with_crew.merge(crew, on = 'tconst')
movie_rating_with_crew.head()
# Out:
#      title_id  ordering                                              title  \
# 0   tt0369610        10                                      Джурасик свят
# 1   tt0381957         1                                  Cloud Cuckoo Land
# 2   tt0401729        10                       Джон Картер: Мiж двох свiтiв
# 3  tt10010134         1  Versailles Rediscovered - The Sun King's Vanis...
# 4  tt10084780         1                         Vinara sodara veera kumara
#
#   region language     types attributes  is_original_title      tconst  \
# 0     BG       bg       NaN        NaN                0.0   tt0369610
# 1     GB      NaN       NaN        NaN                0.0   tt0381957
# 2     UA      NaN       NaN        NaN                0.0   tt0401729
# 3    NaN      NaN  original        NaN                1.0  tt10010134
# 4     IN      NaN       NaN        NaN                0.0  tt10084780
#
#    averagerating  numvotes                                      primary_title  \
# 0            7.0    539338                                     Jurassic World
# 1            7.6        23                                  Cloud Cuckoo Land
# 2            6.6    241792                                        John Carter
# 3            7.0         5  Versailles Rediscovered - The Sun King's Vanis...
# 4            8.3        30                         Vinara sodara veera kumara
#
#                                       original_title  start_year  \
# 0                                     Jurassic World        2015
# 1                                  Cloud Cuckoo Land        2012
# 2                                        John Carter        2012
# 3  Versailles Rediscovered - The Sun King's Vanis...        2019
# 4                         Vinara sodara veera kumara        2019
#
#    runtime_minutes                   genres   directors  \
# 0            124.0  Action,Adventure,Sci-Fi   nm1119880
# 1             92.0                    Drama   nm1458371
# 2            132.0  Action,Adventure,Sci-Fi   nm0004056
# 3             52.0              Documentary   nm2205937
# 4              NaN            Drama,Romance  nm10574727
#
#                                              writers
# 0  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341
# 1                                nm1458371,nm1461088
# 2            nm0004056,nm0028764,nm0149290,nm0123194
# 3           nm2205937,nm1355962,nm10542772,nm0873469
# 4                                                NaN

# %%
movie_rating_with_crew = movie_rating_with_crew.merge(principals, on = 'tconst')
movie_rating_with_crew.head()
# Out:
#     title_id  ordering_x          title region language types attributes  \
# 0  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 1  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 2  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 3  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
# 4  tt0369610          10  Джурасик свят     BG       bg   NaN        NaN
#
#    is_original_title     tconst  averagerating  ...  start_year  \
# 0                0.0  tt0369610            7.0  ...        2015
# 1                0.0  tt0369610            7.0  ...        2015
# 2                0.0  tt0369610            7.0  ...        2015
# 3                0.0  tt0369610            7.0  ...        2015
# 4                0.0  tt0369610            7.0  ...        2015
#
#   runtime_minutes                   genres  directors  \
# 0           124.0  Action,Adventure,Sci-Fi  nm1119880
# 1           124.0  Action,Adventure,Sci-Fi  nm1119880
# 2           124.0  Action,Adventure,Sci-Fi  nm1119880
# 3           124.0  Action,Adventure,Sci-Fi  nm1119880
# 4           124.0  Action,Adventure,Sci-Fi  nm1119880
#
#                                              writers ordering_y     nconst  \
# 0  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341         10  nm0189777
# 1  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341          1  nm0695435
# 2  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341          2  nm0397171
# 3  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341          3  nm1339223
# 4  nm0415425,nm0798646,nm1119880,nm2081046,nm0000341          4  nm0339460
#
#    category       job  characters
# 0  producer  producer         NaN
# 1     actor       NaN    ["Owen"]
# 2   actress       NaN  ["Claire"]
# 3     actor       NaN    ["Gray"]
# 4   actress       NaN   ["Karen"]
#
# [5 rows x 23 columns]

# %%
movie_rating_with_director = movie_rating_with_crew[['primary_title','directors', 'averagerating']]
movie_rating_with_director = movie_rating_with_director.drop_duplicates()
movie_rating_with_director.head(50)
# Out:
#                                          primary_title            directors  \
# 0                                       Jurassic World            nm1119880
# 10                                   Cloud Cuckoo Land            nm1458371
# 20                                         John Carter            nm0004056
# 30   Versailles Rediscovered - The Sun King's Vanis...            nm2205937
# 40                          Vinara sodara veera kumara           nm10574727
# 50                                 Alice in Wonderland            nm0000318
# 60                                From Paris with Love            nm0603628
# 70                                   Dark Buenos Aires            nm1413776
# 80                                   The Bourne Legacy            nm0006904
# 90                                           Snatched!            nm1370224
# 97                                           Limitless            nm1139726
# 107                                         Motherland            nm1823281
# 117                                       African Cats  nm0774582,nm0288144
# 127                                       Spark Riders            nm2996734
# 135                                  Caller ID: Entity            nm0956703
# 145                                    Captain Thunder            nm0379872
# 155                               My Girlfriend's Back            nm0044021
# 165                                        Broken City            nm0400441
# 175       The Arrested Development Documentary Project            nm1753190
# 182                                 The Mountain Thief            nm3047127
# 192                                        Sister Mary            nm1980830
# 199                                            Rollers            nm0031408
# 209                                       The Way Home            nm0004165
# 219                                        Bon appétit            nm1266768
# 229                                    Bridge of Names  nm1519293,nm1181214
# 239                                       Room in Rome            nm0575523
# 249                               A Trouble in Dollars            nm2985471
# 259                                         Space Dogs  nm3575075,nm0882296
# 269                                         References            nm2921854
# 274                                     Trail of Blood  nm1463716,nm1473041
# 284                                             Lahore            nm3114227
# 294                                 Life at the Resort  nm1102188,nm0898187
# 304                                      Left for Dead            nm3042038
# 314                                         Casting By            nm0231999
# 324                                      The Last Song            nm1455688
# 334                                             The FP  nm1875808,nm1060930
# 344                       The Lady and the Taxi Driver            nm0463512
# 352                                           Enthiran            nm0788171
# 362                                 Bullet to the Head            nm0001353
# 372                Lamhaa: The Untold Story of Kashmir            nm1194320
# 382                                  Zombies Unleashed            nm1975174
# 392                                    Jhootha Hi Sahi            nm1063072
# 402                                        SubHysteria            nm1124442
# 412                                     Claustrophobia            nm2532823
# 421                                           Yeardley            nm3209281
# 431                                           The Pack            nm1035941
# 441                                        Close Enemy            nm0040286
# 451                                   The Great Gatsby            nm0525303
# 461                                              Dredd            nm0871428
# 471                                          Teenagers            nm3251909
#
#      averagerating
# 0              7.0
# 10             7.6
# 20             6.6
# 30             7.0
# 40             8.3
# 50             6.5
# 60             6.5
# 70             3.4
# 80             6.7
# 90             5.9
# 97             7.4
# 107            8.0
# 117            7.6
# 127            7.2
# 135            4.2
# 145            2.9
# 155            2.5
# 165            6.2
# 175            6.7
# 182            7.0
# 192            4.3
# 199            5.0
# 209            6.0
# 219            6.3
# 229            5.2
# 239            6.2
# 249            5.6
# 259            5.2
# 269            6.0
# 274            4.3
# 284            6.4
# 294            5.4
# 304            5.9
# 314            7.6
# 324            6.0
# 334            5.6
# 344            4.6
# 352            7.1
# 362            5.7
# 372            5.1
# 382            2.5
# 392            6.2
# 402            6.9
# 412            6.2
# 421            9.0
# 431            4.8
# 441            5.5
# 451            7.3
# 461            7.1
# 471            5.9

# %%
movie_rating_with_director_top10 = movie_rating_with_director.groupby(['directors']).mean().head(10)
movie_rating_with_director_top10 = movie_rating_with_director_top10.merge(name_basics, left_on = 'directors', right_on = 'nconst')

movie_rating_with_director_top10
# Out:
#    averagerating     nconst     primary_name  birth_year  death_year  \
# 0       6.900000  nm0000080     Orson Welles      1915.0      1985.0
# 1       6.700000  nm0000095      Woody Allen      1935.0         NaN
# 2       6.360000  nm0000108       Luc Besson      1959.0         NaN
# 3       6.500000  nm0000110  Kenneth Branagh      1960.0         NaN
# 4       5.600000  nm0000118   John Carpenter      1948.0         NaN
# 5       6.266667  nm0000123   George Clooney      1961.0         NaN
# 6       5.500000  nm0000127       Wes Craven      1939.0      2015.0
# 7       7.100000  nm0000128    Russell Crowe      1964.0         NaN
# 8       5.000000  nm0000136      Johnny Depp      1963.0         NaN
# 9       6.650000  nm0000142   Clint Eastwood      1930.0         NaN
#
#                    primary_profession                         known_for_titles
# 0               actor,director,writer  tt0048393,tt0052311,tt0057427,tt0033467
# 1               writer,director,actor  tt0091167,tt0079522,tt0075686,tt0097123
# 2            writer,producer,director  tt2872732,tt0119116,tt0110413,tt0100263
# 3             actor,producer,director  tt0107616,tt0097499,tt3402236,tt0116477
# 4  soundtrack,writer,music_department  tt0080749,tt0093777,tt0077651,tt0082340
# 5             actor,producer,director  tt2177771,tt1193138,tt1124035,tt0465538
# 6            writer,producer,director  tt0105121,tt0111686,tt0087800,tt0117571
# 7           actor,soundtrack,producer  tt0268978,tt1707386,tt0119488,tt0172495
# 8           actor,producer,soundtrack  tt0325980,tt0449088,tt0408236,tt0383574
# 9             actor,producer,director  tt0405159,tt0105695,tt1205489,tt0112579

# %% [markdown]
# # Questions

# %% [markdown]
# ## Question 1

# %%
# What kind of movie would be a good choice?

# %% [markdown]
# ### Q1 conclusion

# %%
#Based on yearly change of each type of movie's gross, Adventure would be a good choice.

# %%
movie_type_yearly_change.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='start_year'>

# %% [markdown]
# ## Question 2

# %%
#To increase world gross of a movie, which element should be top priority? and which one is last one to be considered?

# %% [markdown]
# ### Q2 conclusion

# %%
#Within a reasonable range, budget should be considered most, and movie time is less impact to gross.

# %%
movie_rating.corr()["worldwide_gross"].nsmallest(3)
# Out:
# id                -0.037656
# profit_ratio       0.080536
# runtime_minutes    0.300475
# Name: worldwide_gross, dtype: float64

# %%
movie_rating.corr()['worldwide_gross'].nlargest(2)
# Out:
# worldwide_gross      1.000000
# production_budget    0.782909
# Name: worldwide_gross, dtype: float64

# %% [markdown]
# ## Question 3

# %%
#Best Three director

# %% [markdown]
# ### Q3 conclusion

# %%
#Orson Welles, Woody Allen, Luc Besson

# %%
movie_rating_with_director_top10.head(3)
# Out:
#    averagerating     nconst  primary_name  birth_year  death_year  \
# 0           6.90  nm0000080  Orson Welles      1915.0      1985.0
# 1           6.70  nm0000095   Woody Allen      1935.0         NaN
# 2           6.36  nm0000108    Luc Besson      1959.0         NaN
#
#          primary_profession                         known_for_titles
# 0     actor,director,writer  tt0048393,tt0052311,tt0057427,tt0033467
# 1     writer,director,actor  tt0091167,tt0079522,tt0075686,tt0097123
# 2  writer,producer,director  tt2872732,tt0119116,tt0110413,tt0100263

# %% [markdown]
# # Conclusion / Recommendations

# %%
#Most profit movie would be advanture type with suficient budgets, top 3 rate movie diretor are Orson Welles, Woody Allen, Luc Besson.

# %% [markdown]
# # Future Work

# %%
#With more time, I would like to dig into relationship between crews, try to find a best coroperation team.
